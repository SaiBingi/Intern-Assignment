# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiBingi/Intern-Assignment/blob/main/InternAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

test_df = pd.read_excel("Input_2.xlsx")

# %%
type(test_df)
# Out:
# pandas.core.frame.DataFrame

# %%
test_df.rename(columns={"id": "Username"})
# Out:
#         Name  Username Chapter Tag Concept Test 1 - score  \
# 0    Darshan        34       C8S10                      -
# 1      Durga        35       C8S10                      -
# 2      Idhaz        36       C8S10                      2
# 3    Kishore        37       C8S10                      -
# 4       Mano        38       C8S10                      2
# 5     Nandha        39       C8S10                      -
# 6   Nandhini        40       C8S10                      2
# 7     Rubika        42       C8S10                      3
# 8      Saila        43       C8S10                      2
# 9    Shankar        44       C8S10                      -
# 10     Tarun        45       C8S10                      -
# 11    Thanis        46       C8S10                      -
#
#    Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                      -                         -
# 1                                      -                         -
# ...

# %%
new_df = pd.DataFrame()

# %%
new_df[["Name", "Username", "Chapter Tag"]] = test_df[["Name", "id", "Chapter Tag"]]

# %%
new_df
# Out:
#         Name  Username Chapter Tag
# 0    Darshan        34       C8S10
# 1      Durga        35       C8S10
# 2      Idhaz        36       C8S10
# 3    Kishore        37       C8S10
# 4       Mano        38       C8S10
# 5     Nandha        39       C8S10
# 6   Nandhini        40       C8S10
# 7     Rubika        42       C8S10
# 8      Saila        43       C8S10
# 9    Shankar        44       C8S10
# 10     Tarun        45       C8S10
# 11    Thanis        46       C8S10

# %%
df = pd.DataFrame()
for i in range(len(new_df["Name"])):
  row = new_df.loc[i]
  for j in range(8):
    new_df = new_df.append({"Name": row.Name, "Username": row.Username, "Chapter Tag": row["Chapter Tag"]}, ignore_index=True)

new_df.sort_values(by="Name", ignore_index=True, inplace=True)

# %%
new_df["Test_Name"] = pd.Series(["Concept Test 1", "Concept Test 2", "Concept Test 3", "Concept Test 4", "Concept Test 5", "Full Chapter Test 1", "Full Chapter Test 2", "Topic Test 1", "Topic Test 2"]*len(new_df["Name"]))

# %%
new_df["score"] = pd.Series()
new_df["time-taken (seconds)"] = pd.Series()
new_df["answered"] = pd.Series()
new_df["correct"] = pd.Series()
new_df["wrong"] = pd.Series()
new_df["skipped"] = pd.Series()
# Out:
# <ipython-input-241-42ddf740d255>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_df["score"] = pd.Series()
# <ipython-input-241-42ddf740d255>:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_df["time-taken (seconds)"] = pd.Series()
# <ipython-input-241-42ddf740d255>:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_df["answered"] = pd.Series()
# <ipython-input-241-42ddf740d255>:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_df["correct"] = pd.Series()
# ...

# %%
new_df
# Out:
#          Name  Username Chapter Tag            Test_Name  score  \
# 0     Darshan        34       C8S10       Concept Test 1    NaN
# 1     Darshan        34       C8S10       Concept Test 2    NaN
# 2     Darshan        34       C8S10       Concept Test 3    NaN
# 3     Darshan        34       C8S10       Concept Test 4    NaN
# 4     Darshan        34       C8S10       Concept Test 5    NaN
# 5     Darshan        34       C8S10  Full Chapter Test 1    NaN
# 6     Darshan        34       C8S10  Full Chapter Test 2    NaN
# 7     Darshan        34       C8S10         Topic Test 1    NaN
# 8     Darshan        34       C8S10         Topic Test 2    NaN
# 9       Durga        35       C8S10       Concept Test 1    NaN
# 10      Durga        35       C8S10       Concept Test 2    NaN
# 11      Durga        35       C8S10       Concept Test 3    NaN
# 12      Durga        35       C8S10       Concept Test 4    NaN
# 13      Durga        35       C8S10       Concept Test 5    NaN
# ...

# %%
c = 3
r_c = 0
for i in range(len(new_df["Name"])):

  new_df.loc[i, "score"] = test_df.iloc[r_c, c] 
  c += 1
  new_df.loc[i, "time-taken (seconds)"] = test_df.iloc[r_c, c] 
  c += 1
  new_df.loc[i, "answered"] = test_df.iloc[r_c, c] 
  c += 1
  new_df.loc[i, "correct"] = test_df.iloc[r_c, c] 
  c += 1
  new_df.loc[i, "wrong"] = test_df.iloc[r_c, c] 
  c += 1
  new_df.loc[i, "skipped"] = test_df.iloc[r_c, c] 
  c += 1

  if (c % 57) == 0:
    r_c += 1  
    c = 3

  
new_df
# Out:
#          Name  Username Chapter Tag            Test_Name score  \
# 0     Darshan        34       C8S10       Concept Test 1     -
# 1     Darshan        34       C8S10       Concept Test 2     3
# 2     Darshan        34       C8S10       Concept Test 3     6
# 3     Darshan        34       C8S10       Concept Test 4     3
# 4     Darshan        34       C8S10       Concept Test 5     3
# 5     Darshan        34       C8S10  Full Chapter Test 1     3
# 6     Darshan        34       C8S10  Full Chapter Test 2     6
# 7     Darshan        34       C8S10         Topic Test 1     3
# 8     Darshan        34       C8S10         Topic Test 2     6
# 9       Durga        35       C8S10       Concept Test 1     -
# 10      Durga        35       C8S10       Concept Test 2     -
# 11      Durga        35       C8S10       Concept Test 3     -
# 12      Durga        35       C8S10       Concept Test 4     -
# 13      Durga        35       C8S10       Concept Test 5     4
# ...

# %%
# ["score", "time-taken (seconds)", "answered", "correct", "wrong", "skipped"]
# test_df.iloc[0, [3, 4, 5, 6, 7, 8]]
# new_df.loc[i, ["score", "time-taken (seconds)", "answered", "correct", "wrong", "skipped"]]
# test_df

pd.set_option('display.max_rows', None)
swap_list = ["Name", "Username", "Chapter Tag", "Test_Name","answered","correct","score","skipped","time-taken (seconds)", "wrong"]

# %%
new_df = new_df.reindex(columns=swap_list)
new_df.loc[0, "score"] = test_df.iloc[0, 3]

new_df
# Out:
#          Name  Username Chapter Tag            Test_Name answered correct  \
# 0     Darshan        34       C8S10       Concept Test 1        -       -
# 1     Darshan        34       C8S10       Concept Test 2        4       3
# 2     Darshan        34       C8S10       Concept Test 3        8       6
# 3     Darshan        34       C8S10       Concept Test 4        3       3
# 4     Darshan        34       C8S10       Concept Test 5        4       3
# 5     Darshan        34       C8S10  Full Chapter Test 1        3       3
# 6     Darshan        34       C8S10  Full Chapter Test 2        8       6
# 7     Darshan        34       C8S10         Topic Test 1        6       3
# 8     Darshan        34       C8S10         Topic Test 2       10       6
# 9       Durga        35       C8S10       Concept Test 1        -       -
# 10      Durga        35       C8S10       Concept Test 2        -       -
# 11      Durga        35       C8S10       Concept Test 3        -       -
# ...

# %%
import numpy as np 

new_df.replace("-", np.nan, inplace=True)

new_df
# Out:
#          Name  Username Chapter Tag            Test_Name  answered  correct  \
# 0     Darshan        34       C8S10       Concept Test 1       NaN      NaN
# 1     Darshan        34       C8S10       Concept Test 2       4.0      3.0
# 2     Darshan        34       C8S10       Concept Test 3       8.0      6.0
# 3     Darshan        34       C8S10       Concept Test 4       3.0      3.0
# 4     Darshan        34       C8S10       Concept Test 5       4.0      3.0
# 5     Darshan        34       C8S10  Full Chapter Test 1       3.0      3.0
# 6     Darshan        34       C8S10  Full Chapter Test 2       8.0      6.0
# 7     Darshan        34       C8S10         Topic Test 1       6.0      3.0
# 8     Darshan        34       C8S10         Topic Test 2      10.0      6.0
# 9       Durga        35       C8S10       Concept Test 1       NaN      NaN
# 10      Durga        35       C8S10       Concept Test 2       NaN      NaN
# ...

# %%
new_df.dropna(axis='index', how="any", subset=["answered","correct","score","skipped","time-taken (seconds)", "wrong"], inplace=True)

# %%
new_df.sort_values(by="Name", ignore_index=True, inplace=True)
new_df
# Out:
#         Name  Username Chapter Tag            Test_Name  answered  correct  \
# 0    Darshan        34       C8S10       Concept Test 2       4.0      3.0
# 1    Darshan        34       C8S10       Concept Test 3       8.0      6.0
# 2    Darshan        34       C8S10       Concept Test 4       3.0      3.0
# 3    Darshan        34       C8S10       Concept Test 5       4.0      3.0
# 4    Darshan        34       C8S10  Full Chapter Test 1       3.0      3.0
# 5    Darshan        34       C8S10  Full Chapter Test 2       8.0      6.0
# 6    Darshan        34       C8S10         Topic Test 1       6.0      3.0
# 7    Darshan        34       C8S10         Topic Test 2      10.0      6.0
# 8      Durga        35       C8S10       Concept Test 5       5.0      4.0
# 9      Durga        35       C8S10  Full Chapter Test 1       5.0      4.0
# 10     Durga        35       C8S10  Full Chapter Test 2      10.0      7.0
# ...
